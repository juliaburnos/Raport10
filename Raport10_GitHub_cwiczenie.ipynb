# %% [markdown]
# <a href="https://colab.research.google.com/github/juliaburnos/Raport10/blob/main/Raport10_GitHub_cwiczenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Profil
#
# *   [Dataquest](https://app.dataquest.io/profile/128562)
# *   [Datacamp](https://www.datacamp.com/portfolio/128562-b648704d-729d-4625-8c50-507e858ff776)
# * [Codewars](https://www.codewars.com/users/julia.burnos)

# %% [markdown]
# brakuje CodeWars

# %% [markdown]
# # Raport 1

# %%
print("Potwierdzam wykonanie poleceń polegających na: \n - Odnaleźć swój zeszyt na tej tablicy w sekcji Zeszyty studentów; \n - Zmiana nazwy zgodnie z wytycznymi podanymi przez prowadzącego. \n - Utworzenie sekcji Profil na początku zeszytu. \n - Utworzenie sekcji Raport 1. \n - W sekcji profil umieściłam linki odnoszące się do moich profili na: Dataquest, Datacamp. ")
# Out:
# Potwierdzam wykonanie poleceń polegających na:
#  - Odnaleźć swój zeszyt na tej tablicy w sekcji Zeszyty studentów;
#  - Zmiana nazwy zgodnie z wytycznymi podanymi przez prowadzącego.
#  - Utworzenie sekcji Profil na początku zeszytu.
#  - Utworzenie sekcji Raport 1.
#  - W sekcji profil umieściłam linki odnoszące się do moich profili na: Dataquest, Datacamp.

# %% [markdown]
# # Raport 2

# %% [markdown]
# ##Certyfikat
# Certyfikat ukończenia kursu "Introduction to Python Programming for Data Science"
# ![raport_1.png](data:image/png;base64,...)
#
# [Link do certyfikatu](https://app.dataquest.io/view_cert/TPWT314JX6NUN1GZXNGO)

# %% [markdown]
# ## Wrażenia z kursu
#
# Kurs "Introduction to Python Programming for Data Science" okazał się bardzo wartościowym doświadczeniem dla każdego, kto chce rozpocząć swoją przygodę z Pythonem. Program został dobrze przemyślany, a materiały były jasno przedstawione, co ułatwiało przyswajanie wiedzy zarówno osobom początkującym, jak i tym, które miały już pewne podstawy programowania.

# %% [markdown]
# # Raport 3

# %% [markdown]
# Wykonano zadanie na platformie CodeWars. Zamieszczono link do zadania, a niżej umieszczono kod.
# https://www.codewars.com/kata/54ff3102c1bad923760001f3/solutions/python

# %%
def get_count(sentence):
    vowels = "aeiou"
    count = 0
    for char in sentence:
        if char in vowels:
            count += 1
    return count

# %% [markdown]
# #Raport 4

# %% [markdown]
# ## Certyfikat
# Certyfikat ukończenia kursu "Basic Operators and Data Structures in Python"
# ![raport_2.jpeg](data:image/jpeg;base64,...)
# [Link do certyfikatu](https://app.dataquest.io/view_cert/CXVXI7K47QR8F13Y452J)

# %% [markdown]
# ##Wrażenia z kursu
#
# Kurs "Basic Operators and Data Structures in Python" okazał się świetnym wprowadzeniem do kluczowych elementów języka, które są niezbędne w codziennej pracy z Pythonem. Dzięki dobrze przygotowanym materiałom i praktycznym ćwiczeniom można było szybko przyswoić wiedzę na temat podstawowych operatorów oraz struktur danych.

# %% [markdown]
# ##CodeWars
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Raport 5

# %% [markdown]
# ## Certyfikat

# %% [markdown]
# Ukończono lekcję "Python Functions: Using Built-in Functions and Creating Functions".
# ![image.png](data:image/png;base64,...)
# Uwagi:
# *   Poznano wbudowane funkcje w Pythonie, które znacząco upraszczają programowanie i zaoszczędzają czas;
# *   Przećwiczono składnie w Pythonie -- tworzenie funkcji z jednym parametrem, więcej niż z jednym parametrem i funkcji, które bezpośrednio zwraca wynik wyrażenia;
# *   Dzięki tej lekcji lepiej zrozumiano różnicę między parametrami a argumentami, które stosujemy w tworzeniu funkcji.

# %% [markdown]
# ##CodeWars
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## CodeWars: kółko i krzyżyk

# %%
def is_solved(board):
    flat = [cell for row in board for cell in row]
    lines = []
    for i in range(3):
        lines.append(board[i])
        lines.append([board[0][i], board[1][i], board[2][i]])
    lines.append([board[0][0], board[1][1], board[2][2]])
    lines.append([board[0][2], board[1][1], board[2][0]])
    for line in lines:
        if line.count(line[0]) == 3 and line[0] != 0:
            return line[0]
    return 0 if 0 not in flat else -1

# %% [markdown]
# # Raport 6

# %% [markdown]
# ## Wykonanie lekcji
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Raport 7

# %% [markdown]
# # Raport 8

# %% [markdown]
# ## Certyfikat

# %% [markdown]
# # Raport 10

# %% [markdown]
# ## GitHub
# 1. Założono konto na platformie GitHub.
# 2. Link do profilu na GitHub: https://github.com/juliaburnos.
# 3. Założono nowy Repository o nazwie Raport10.
# 4. Link do Repository: https://github.com/juliaburnos/Raport10/blob/main/README.md
# 5. Utworzono notatnik z Raportem 8.
# 6.
# 7. Podano link: https://github.com/juliaburnos/Raport10/commit/32494aa0af9da039c17dd2814961475c656af8e3
# 8.
